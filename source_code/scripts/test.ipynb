# %%
from PIL import Image

# %%
from io import BytesIO
from PIL import Image

with BytesIO() as output:
    with Image.open('./images/test.bmp') as img:
        data = img.convert('1')

# %%
data.tobytes()
# Out:
# b'
# ...

# %%
imgByteArr

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-a40fc8588245> in <module>()
#       1 import io
#       2 imgByteArr = io.BytesIO()
# ----> 3 image.save(imgByteArr, format='BMP')
#       4 imgByteArr = imgByteArr.getvalue()
#
# NameError: name 'image' is not defined
